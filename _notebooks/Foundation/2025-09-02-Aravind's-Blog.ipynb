# %% [markdown]
# ---
# layout: post
# title: My Blog
# description: my personal blog in CSSE
# comments: true
# permalink: /myblog
# ---

# %% [markdown]
# My Personal Blog
#
# My first major step was to streamline my tooling on macOS. We adopted Homebrew, a powerful package manager that has made installing and managing command-line utilities incredibly efficient. With a single command, I was able to set up tools like wget and, most critically, Git. This foundational step has made my workflow much cleaner and more organized.
#
# With Git in place, I was able to fork my teacher's repository on GitHub. This action is a cornerstone of collaborative development, as it creates a personal copy of the codebase. It allows me to work on new features or bug fixes independently before submitting my changes back to the main project, ensuring a structured and non-disruptive workflow.
#
# Mastering the Jupyter Notebook
#
# Early on, I recognized the value of Jupyter Notebooks as more than just a place to write code. It is an interactive computing environment that integrates code, output, and explanatory text in a single document. I used this to run jokes.
#
# Developing a Personal Web Presence
#
# A significant part of our recent work has been personalizing our blogs to showcase our projects. I gained practical experience by modifying my blog's theme to create a custom look and feel. This exercise taught me how to work with template files and appreciate the power of front-end customization.
#
# Furthermore, I was able to implement a dynamic, in-motion background for my page. By integrating a small JavaScript snippet, I was able to load a background image and create an animated effect, which added a layer of visual polish and demonstrated my ability to integrate different coding languages.
#
# Adopting Agile Methodologies
#
# Finally, I had the opportunity to collaborate with my team using a Kanban board. This is a visual project management tool that has significantly improved our efficiency. By categorizing tasks into columns like "To-Do," "In Progress," and "Done," we gained a clear, real-time overview of our project's status. This practice has not only helped us manage tasks but has also fostered better communication and accountability within the team.
#
# In conclusion, the journey has been about much more than just writing code. I've learned to build a professional-grade toolset, document my work effectively, customize my online presence, and collaborate with a team. I am excited to continue applying these skills in future projects.

# %%
---
layout: post
title: My Blog
description: A blog about my personal experiences in CSSE
categories: ['DevOps']
permalink: /tools/github_pages
breadcrumb: True
---

# %% [markdown]
# ---
# layout: blogs
# title: My Blog
# search_exclude: true
# permalink: /navigation/blogs/
# ---
# Getting Started with Tools
#
# The first big step was getting my development environment set up. We started with Homebrew, a package manager for macOS. I thought it would be complicated, but it was surprisingly easy. A single line of code in the terminal and I could install powerful tools like wget and Git. This made managing my tools so much simpler.
#
# Next, we tackled Git. I was a little nervous about it, but the most important command I learned was git clone. This let me fork my teacher's repository from GitHub. Forking creates my own copy of the project, so I can work on it independently without affecting the original. It felt like a big deal to have my own version of the code to experiment with.
#
# Working with Jupyter Notebooks
#
# Then came Jupyter Notebooks. At first, it just looked like a document, but I quickly realized how cool it is. It lets me write code and see the output right away, all in the same file. I was able to write and execute code for things like math problems and data visualizations. It's an awesome way to learn and show your work at the same time.
#
# Customizing My Blog
#
# Our blogs are a great way to showcase what we've learned, and I really enjoyed customizing mine. I learned how to change the theme of my blog to make it my own. By editing a few files, I could change the colors and layout. It was a small change that made my page feel much more personal.
#
# I also added a moving background to my blog. I used a JavaScript snippet that takes a background image and makes it an animation. This gave my page a dynamic feel and was a great way to practice working with different code snippets.
#
# Collaborating as a Team
#
# Finally, my team started using a Kanban board. This was probably one of the most useful tools we adopted. It's a visual way to track our progress on a project. We created columns like "To-Do," "In Progress," and "Done." This made it so easy to see who was working on what and what tasks were left. It made our collaboration much more organized and efficient.
#
# Overall, I feel like I’ve grown a lot, not just with my coding skills but also with using professional tools. It's been a great experience, and I'm excited to see what we build next!
#
# Jupiter notebooks is for jokes make it a bit. more proffesional
# Okay, let's refine the tone of the blog post to be more professional and reflect a deeper understanding of Jupyter Notebooks as a serious development tool.
#
# Hello everyone,
#
# I wanted to share a reflection on the progress I've made with my coding tools and processes over the past few weeks. It's been a journey of building a more robust and professional development environment, and I'm proud of the skills I've acquired.
#
# Establishing My Development Environment
#
# My first major step was to streamline my tooling on macOS. We adopted Homebrew, a powerful package manager that has made installing and managing command-line utilities incredibly efficient. With a single command, I was able to set up tools like wget and, most critically, Git. This foundational step has made my workflow much cleaner and more organized.
#
# With Git in place, I was able to fork my teacher's repository on GitHub. This action is a cornerstone of collaborative development, as it creates a personal copy of the codebase. It allows me to work on new features or bug fixes independently before submitting my changes back to the main project, ensuring a structured and non-disruptive workflow.
#
# Mastering the Jupyter Notebook
#
# Early on, I recognized the value of Jupyter Notebooks as more than just a place to write code. It is an interactive computing environment that integrates code, output, and explanatory text in a single document. This has proven to be an invaluable tool for:
#
# Prototyping and Exploration: I can rapidly test new ideas and see the results immediately, which accelerates the learning process.
#
# Documentation and Presentation: By combining code with Markdown cells, I can create detailed, self-contained reports that explain my logic and showcase my findings. This has been particularly useful for demonstrating my work to others.
#
# Developing a Personal Web Presence
#
# A significant part of our recent work has been personalizing our blogs to showcase our projects. I gained practical experience by modifying my blog's theme to create a custom look and feel. This exercise taught me how to work with template files and appreciate the power of front-end customization.
#
# Furthermore, I was able to implement a dynamic, in-motion background for my page. By integrating a small JavaScript snippet, I was able to load a background image and create an animated effect, which added a layer of visual polish and demonstrated my ability to integrate different coding languages.
#
# Adopting Agile Methodologies
#
# Finally, I had the opportunity to collaborate with my team using a Kanban board. This is a visual project management tool that has significantly improved our efficiency. By categorizing tasks into columns like "To-Do," "In Progress," and "Done," we gained a clear, real-time overview of our project's status. This practice has not only helped us manage tasks but has also fostered better communication and accountability within the team.
#
# In conclusion, the journey has been about much more than just writing code. I've learned to build a professional-grade toolset, document my work effectively, customize my online presence, and collaborate with a team. I am excited to continue applying these skills in future projects.
