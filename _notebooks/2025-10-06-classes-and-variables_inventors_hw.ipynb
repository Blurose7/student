# %% [raw]
# ---
# toc: True
# layout: post
# data: tools
# title: Varclasses
# description: Teaching Variables and Classes
# permalink: /csse/fall_2025/javascript/classes-and-variables/hw
# ---

# %% [markdown]
# ## POPCORN HACK 1 A short program about variables

# %%
let name = "Sam";
let age = 10;

console.log("Hi, my name is", name);
console.log("I am", age, "years old.");

let nextYearAge = age + 1;
console.log("Next year I will be", nextYearAge, "years old.");

# %% [markdown]
# ## POPCORN HACK 2 A short program about classes

# %%
// Step 1: Define the Animal class
class Animal {
  constructor(name, sound, kind) {
    this.name = name;
    this.sound = sound;
    this.kind = kind;
  }

  speak() {
    console.log(`${this.name} the ${this.kind} says ${this.sound}!`);
  }

  describe() {
    console.log(`${this.name} is a ${this.kind} and is very friendly!`);
  }
}

// Step 2: Create a list to hold all the animals in the zoo
let zoo = [];

// Step 3: Add animals to the zoo
zoo.push(new Animal("Buddy", "Woof", "Dog"));
zoo.push(new Animal("Mittens", "Meow", "Cat"));
zoo.push(new Animal("Polly", "Squawk", "Parrot"));

// Step 4: Loop through all animals and make them speak and describe
zoo.forEach(animal => {
  animal.speak();
  animal.describe();
});

# %% [markdown]
# ## Homework

# %%
const choices = ["rock", "paper", "scissors"];

while (true) {
  let userChoice = prompt("Choose rock, paper, or scissors (or type 'quit' to exit):");
  if (!userChoice) {
    alert("No choice entered. Exiting game.");
    break;
  }
  
  userChoice = userChoice.toLowerCase();

  if (userChoice === "quit") {
    alert("Thanks for playing!");
    break;
  }

  if (!choices.includes(userChoice)) {
    alert("Invalid choice, please choose rock, paper, or scissors.");
    continue;
  }

  const computerChoice = choices[Math.floor(Math.random() * choices.length)];
  alert("Computer chose: " + computerChoice);

  if (userChoice === computerChoice) {
    alert("It's a tie!");
  } else if (
    (userChoice === "rock" && computerChoice === "scissors") ||
    (userChoice === "scissors" && computerChoice === "paper") ||
    (userChoice === "paper" && computerChoice === "rock")
  ) {
    alert("You win!");
  } else {
    alert("You lose!");
  }
}

# %% [markdown]
# ## Sumbmission!

# %% [markdown]
# https://forms.gle/2aPP6CXFdQnNaE7GA
