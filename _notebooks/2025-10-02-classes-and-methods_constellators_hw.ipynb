# %% [raw]
# ---
# layout: post
# title: Constellators - Classes and Methods HW
# description: These are the homework problems and popcorn hacks, created by the Constellators.
# permalink: /csse/javascript/constellators/classes-and-methods-homework
# author: Adya S, Niharika B, Salma Z, Anika S, Sophie H
# categories: [JavaScript]
# ---

# %% [markdown]
# ## **Classes and Methods**

# %% [markdown]
# ### <u>Popcorn Hack 1 - Dice Roller</u>
#
#
# Instructions:
# Finish the code in the cell below (fill in underlines and add lines of code) so it works as described:
#
# - Create a class called Dice that:
#     - Has a property for the number of sides.
#     - Has a method roll() that returns a random number between 1 and the number of sides.
#
#
# At the bottom, test your game by making a DiceGame object and calling roll() a few times.
#
# The code is currently NOT functional. When you have completed this popcorn hack, the code should work. Have fun!

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Dice Class Solution</title>
</head>
<body>
    <h1>Dice Class Implementation and Test</h1>
    <p>Open your browser's **Console** (usually F12) to see the output of the class instantiation and method calls.</p>
    <div id="results"></div>

    <script>
        /**
         * The Dice class simulates a multi-sided die.
         */
        class **Dice** { // The name of the class should be 'Dice'
            /**
             * Initializes the die with a specified number of sides.
             * @param {number} sides - The number of sides on the die.
             */
            constructor(sides) {
                this.sides = sides; // Number of sides on the dice
            }

            /**
             * Rolls the die and returns a random number between 1 and the number of sides.
             * @returns {number} The result of the roll.
             */
            **roll**() { // The name of the method should be 'roll'
                // Math.random() gives [0, 1), so Math.random() * this.sides gives [0, this.sides)
                // Math.floor(...) makes it [0, this.sides - 1]
                // Adding 1 makes it [1, this.sides]
                return Math.floor(Math.random() * **this.sides**) + 1; // Uses 'this.sides' to define the range
            }
        }


        // Test the Dice class:
        console.log("--- Testing the Dice Class ---");

        // INSTANTIATE A NEW DICE OBJECT WITH A NUMBER OF SIDES (e.g., a 6-sided die)
        const d6 = new Dice(6);
        console.log("Created a 6-sided die (d6).");

        // INSTANTIATE A NEW DICE OBJECT WITH A DIFFERENT NUMBER OF SIDES (e.g., a 20-sided die)
        const d20 = new Dice(20);
        console.log("Created a 20-sided die (d20).");

        // CALL THE ROLL METHOD A FEW TIMES AND PRINT THE RESULTS

        let outputHTML = "<h2>Roll Results:</h2>";

        // d6 rolls
        outputHTML += "<p><strong>D6 (6-sided die) Rolls:</strong></p><ul>";
        for (let i = 0; i < 3; i++) {
            const result = d6.roll();
            console.log(`d6 Roll #${i+1}: ${result}`);
            outputHTML += `<li>Roll ${i+1}: **${result}** (Range: 1-6)</li>`;
        }
        outputHTML += "</ul>";


        // d20 rolls
        outputHTML += "<p><strong>D20 (20-sided die) Rolls:</strong></p><ul>";
        for (let i = 0; i < 3; i++) {
            const result = d20.roll();
            console.log(`d20 Roll #${i+1}: ${result}`);
            outputHTML += `<li>Roll ${i+1}: **${result}** (Range: 1-20)</li>`;
        }
        outputHTML += "</ul>";

        // Output results to the DOM
        document.getElementById('results').innerHTML = outputHTML;
        console.log("--- Test Complete. Results displayed on the page and in the Console. ---");
    </script>
</body>
</html>

# %% [markdown]
# ### <u>Popcorn Hack 2 - Pet Simulator</u>
#
#
# This hack is a bit more complicated than the first. Points will be awarded based on effort and completion.
#
#
# Analyze the block of code below. Then, complete the following instructions:
#
#
# 1) Create a simple Pet class by filling in the _________.
#
# 2) Add at least 2 properties (like hunger, energy, or happiness). EX: Stats decrease over time.
#
# 3) Add at least two functioning methods (such as feed, play, or sleep) EX: Buttons increase stats.
#
# 4) Give your pet a name and print their current properties.
#
# 5) Bonus: Add a "status" method to print all your pet's stats.
#
#
# The code is currently NOT functional. When you have completed this popcorn hack, the code should work. Have fun!

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Virtual Pet Simulator</title>
    <!-- Load Tailwind CSS -->
    <script src="https://cdn.tailwindcss.com"></script>
    <style>
        @import url('https://fonts.googleapis.com/css2?family=Inter:wght@400;600;800&display=swap');
        body {
            font-family: 'Inter', sans-serif;
            background-color: #f7f7f7;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh;
        }
        .stat-bar-container {
            height: 1rem;
            border-radius: 9999px;
            overflow: hidden;
        }
    </style>
</head>
<body class="p-4">

    <!-- Pet Card -->
    <div id="pet-card" class="bg-white shadow-2xl rounded-xl p-8 max-w-sm w-full transition-all duration-300">

        <div class="text-center mb-6">
            <div class="text-6xl mb-4" id="pet-emoji">🐶</div>
            <h1 class="text-3xl font-extrabold text-gray-800" id="pet-name"></h1>
            <p class="text-sm text-gray-500 mt-1" id="pet-message">Ready to play!</p>
        </div>

        <!-- Status Bars -->
        <div class="space-y-4 mb-8">
            <div class="status-item">
                <div class="flex justify-between items-center mb-1">
                    <span class="text-sm font-semibold text-gray-700">Hunger 🍖</span>
                    <span class="text-sm font-bold text-red-500" id="hunger-value">5/10</span>
                </div>
                <div class="stat-bar-container bg-red-100">
                    <div id="hunger-bar" class="h-full bg-red-500 transition-all duration-500" style="width: 50%;"></div>
                </div>
            </div>

            <div class="status-item">
                <div class="flex justify-between items-center mb-1">
                    <span class="text-sm font-semibold text-gray-700">Energy ⚡</span>
                    <span class="text-sm font-bold text-yellow-500" id="energy-value">5/10</span>
                </div>
                <div class="stat-bar-container bg-yellow-100">
                    <div id="energy-bar" class="h-full bg-yellow-500 transition-all duration-500" style="width: 50%;"></div>
                </div>
            </div>

            <div class="status-item">
                <div class="flex justify-between items-center mb-1">
                    <span class="text-sm font-semibold text-gray-700">Happiness 😊</span>
                    <span class="text-sm font-bold text-green-500" id="happiness-value">5/10</span>
                </div>
                <div class="stat-bar-container bg-green-100">
                    <div id="happiness-bar" class="h-full bg-green-500 transition-all duration-500" style="width: 50%;"></div>
                </div>
            </div>
        </div>

        <!-- Actions -->
        <div class="flex justify-between space-x-4">
            <button id="feed-btn" class="flex-1 py-3 px-4 bg-green-600 hover:bg-green-700 text-white font-bold rounded-lg shadow-md transition duration-150 transform hover:scale-[1.02]">
                Feed
            </button>
            <button id="play-btn" class="flex-1 py-3 px-4 bg-blue-600 hover:bg-blue-700 text-white font-bold rounded-lg shadow-md transition duration-150 transform hover:scale-[1.02]">
                Play
            </button>
            <button id="sleep-btn" class="flex-1 py-3 px-4 bg-gray-500 hover:bg-gray-600 text-white font-bold rounded-lg shadow-md transition duration-150 transform hover:scale-[1.02]">
                Sleep
            </button>
        </div>
    </div>


    <script>
        // Use a global object to hold DOM references for cleaner code
        const DOM = {
            name: document.getElementById('pet-name'),
            message: document.getElementById('pet-message'),
            emoji: document.getElementById('pet-emoji'),
            hunger: { value: document.getElementById('hunger-value'), bar: document.getElementById('hunger-bar') },
            energy: { value: document.getElementById('energy-value'), bar: document.getElementById('energy-bar') },
            happiness: { value: document.getElementById('happiness-value'), bar: document.getElementById('happiness-bar') },
            feedBtn: document.getElementById('feed-btn'),
            playBtn: document.getElementById('play-btn'),
            sleepBtn: document.getElementById('sleep-btn'),
        };

        /**
         * The VirtualPet class simulates a simple pet with core needs.
         * Stats are capped between 0 and 10.
         */
        class **VirtualPet** { // The name of the class should be 'VirtualPet'
            constructor(name) {
                this.name = name;
                this.hunger = 5;
                this.energy = 5;
                this.happiness = 5;
            }

            /**
             * Allows user to feed the pet.
             * Increases energy and happiness, decreases hunger.
             */
            feed() {
                // Bounds checking: Use Math.min and Math.max to keep stats between 0 and 10
                this.energy = Math.min(10, this.energy + 2);
                this.hunger = Math.max(0, this.hunger - 3);
                this.happiness = Math.min(10, this.happiness + 1);

                this.logAction("has been fed a tasty treat! 😋");
                this.updateMessage("That was delicious!");
            }

            /**
             * Allows user to play with the pet.
             * Decreases energy, increases hunger and happiness.
             */
            play() {
                if (this.energy <= 0) {
                    this.updateMessage("I'm too tired! I need to sleep or rest. 😴");
                    this.logAction("is too tired to play!");
                    return;
                }

                this.energy = Math.max(0, this.energy - 2);
                this.hunger = Math.min(10, this.hunger + 2);
                this.happiness = Math.min(10, this.happiness + 3);

                this.logAction("is playing happily! 🎾");
                this.updateMessage("Yippee! Let's play again!");
                this.checkVitals();
            }

            /**
             * Allows the pet to sleep and recover energy.
             */
            sleep() {
                this.energy = Math.min(10, this.energy + 4);
                this.hunger = Math.min(10, this.hunger + 1); // Get a little hungry while sleeping
                this.happiness = Math.min(10, this.happiness + 1);

                this.logAction("is resting and recharging. 💤");
                this.updateMessage("Zzz... Much better now.");
                this.checkVitals();
            }

            /** Checks status and adjusts happiness if conditions are critical. */
            checkVitals() {
                if (this.energy <= 1) {
                    this.happiness = Math.max(0, this.happiness - 1);
                    this.updateMessage(`I'm exhausted! ${this.name} needs sleep now.`);
                }
                if (this.hunger >= 9) {
                    this.happiness = Math.max(0, this.happiness - 1);
                    this.updateMessage(`I'm starving! ${this.name} is very hungry.`);
                }
            }

            /** Helper function to log actions to the browser console. */
            logAction(message) {
                console.log(`[${new Date().toLocaleTimeString()}] ${this.name} ${message}`);
            }

            /** Helper function to update the message display on the card. */
            updateMessage(message) {
                DOM.message.textContent = message;
            }
        }

        // INSTANTIATE PET
        const PET_NAME = "Nova";
        const myPet = new **VirtualPet**(PET_NAME); // give your pet a name
        console.log("Pet initialized:", myPet); // print the properties of your pet to console

        // --- UI Logic ---

        /** Updates the DOM to reflect the pet's current state. */
        function updateUI() {
            // Update Name
            DOM.name.textContent = myPet.name;

            // Update Status Bars
            const stats = [
                { key: 'hunger', barId: 'hunger-bar', valueId: 'hunger-value', color: 'red' },
                { key: 'energy', barId: 'energy-bar', valueId: 'energy-value', color: 'yellow' },
                { key: 'happiness', barId: 'happiness-bar', valueId: 'happiness-value', color: 'green' }
            ];

            stats.forEach(stat => {
                const percent = (myPet[stat.key] / 10) * 100;
                DOM[stat.key].bar.style.width = `${percent}%`;
                DOM[stat.key].value.textContent = `${myPet[stat.key]}/10`;

                // Optional: Change bar color based on status (e.g., low energy/happiness turns red)
                const barElement = DOM[stat.key].bar;
                // Remove existing colors
                barElement.className = barElement.className.replace(/bg-\w+-(\d+)/g, '');

                if (stat.key === 'hunger') {
                    // Hunger is bad when high
                    barElement.classList.add(myPet.hunger >= 8 ? 'bg-red-600' : myPet.hunger >= 4 ? 'bg-yellow-500' : 'bg-green-500');
                } else {
                    // Energy and Happiness are good when high
                    barElement.classList.add(myPet[stat.key] <= 3 ? 'bg-red-500' : myPet[stat.key] <= 7 ? 'bg-yellow-500' : 'bg-green-500');
                }
            });
        }

        // Add event listeners to buttons
        DOM.feedBtn.addEventListener('click', () => {
            myPet.feed();
            updateUI();
        });

        DOM.playBtn.addEventListener('click', () => {
            myPet.play();
            updateUI();
        });

        DOM.sleepBtn.addEventListener('click', () => {
            myPet.sleep();
            updateUI();
        });

        // Initialize UI display
        updateUI();
        myPet.updateMessage(`Hello! I am ${myPet.name}. Let's get started!`);

        // Initial console logs (as requested in the prompt)
        console.log(`Initial status of ${myPet.name}:`);
        console.log(`Hunger: ${myPet.hunger}, Energy: ${myPet.energy}, Happiness: ${myPet.happiness}`);
        // output.innerText = "____________________________"; // This line is handled by updateUI() and DOM manipulation
    </script>
</body>
</html>

# %% [markdown]
# ### <u>Homework</u>
#
# Complete the following questions in the next code block.
#
# 1) Create a class Person with properties 'name' and 'age'. Print their properties.
#
# 2) Add a method greet() to your Person class that prints a greeting using the person's name.
#
# 3) Create a class Book with properties 'title', 'author', and 'pages'. Instantiate a book and print its properties.
#
# 4) Add a method read(pages) to your Book class that increments a pagesRead property and prints a message.
#
# 5) Add a method isLongBook() that returns true if pages > 300, otherwise false. Print the result for your book.
#
# 6) Create a class Car with properties 'make', 'model', and 'fuel'. Add methods drive(distance) and refuel(amount). Print messages in each method.
#
# 7) Add a static method info() to your Car class that prints 'Cars are vehicles.'
#
# 8) Create a class ElectricCar that extends Car. Add a property 'battery' and a method charge(amount) that increases battery. Print battery level after charging.
#
# 10) Create a routine that combines your objects: drive a Car, charge an ElectricCar, read pages from a Book, and call greet() on Person. Print outputs for each action.
#
# 11) **Extra Credit:** Submit the original OOP Breakout Game Code (found on [OpenCS](https://github.com/Open-Coding-Society/pages/blob/main/hacks/breakout/breakout.md?plain=1)) after making the following edits:
# - Add another feature to the game: Add a method so that the ball must collide with some bricks twice for a brick to break completely.
# - Edit a method in the ball class to increase/decrease the speed of the ball: Please add a COMMENT on the game code that specifies which line you edited.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
  <title>OOP Homework in JavaScript</title>
  <style>
    body { font-family: Arial, sans-serif; margin: 20px; }
    .output { white-space: pre-wrap; background: #f4f4f4; padding: 10px; border-radius: 5px; }
  </style>
</head>
<body>

<h2>JavaScript OOP Homework</h2>
<div id="output" class="output"></div>

<script>
  const outputDiv = document.getElementById("output");

  function log(message) {
    outputDiv.innerText += message + "\n";
  }

  // 1) Person class
  class Person {
    constructor(name, age) {
      this.name = name;
      this.age = age;
    }

    // 2) greet method
    greet() {
      log(`Hello! My name is ${this.name} and I am ${this.age} years old.`);
    }
  }

  // 3) Book class
  class Book {
    constructor(title, author, totalPages) {
      this.title = title;
      this.author = author;
      this.totalPages = totalPages;
      this.pagesRead = 0;
    }

    // 4) read method
    read(pages) {
      if (this.pagesRead < this.totalPages) {
        const pagesToRead = Math.min(pages, this.totalPages - this.pagesRead);
        this.pagesRead += pagesToRead;
        log(`Read ${pagesToRead} pages of '${this.title}'. Total pages read: ${this.pagesRead}/${this.totalPages}`);
      } else {
        log(`'${this.title}' is already finished!`);
      }
    }

    // 5) isLongBook method
    isLongBook() {
      return this.totalPages > 300;
    }
  }

  // 6) Car class
  class Car {
    constructor(make, model, fuel) {
      this.make = make;
      this.model = model;
      this.fuel = fuel;
    }

    drive(distance) {
      const fuelNeeded = distance * 0.1;
      if (this.fuel >= fuelNeeded) {
        this.fuel -= fuelNeeded;
        log(`The ${this.make} ${this.model} drove ${distance} km. Fuel remaining: ${this.fuel.toFixed(1)} units.`);
      } else {
        log(`Warning! Cannot drive ${distance} km. Not enough fuel (${this.fuel.toFixed(1)} units left).`);
      }
    }

    refuel(amount) {
      this.fuel += amount;
      log(`Refueled by ${amount} units. Total fuel now: ${this.fuel.toFixed(1)} units.`);
    }

    static info() {
      log("Cars are vehicles.");
    }
  }

  // 8) ElectricCar class extending Car
  class ElectricCar extends Car {
    constructor(make, model, battery) {
      super(make, model, 0); // fuel set to 0 for electric cars
      this.battery = battery;
    }

    drive(distance) {
      const chargeNeeded = distance * 0.2;
      if (this.battery >= chargeNeeded) {
        this.battery -= chargeNeeded;
        log(`The ${this.make} ${this.model} (Electric) drove ${distance} km. Battery remaining: ${this.battery.toFixed(1)}%`);
      } else {
        log(`Warning! Cannot drive ${distance} km. Low battery (${this.battery.toFixed(1)}% left).`);
      }
    }

    charge(amount) {
      this.battery = Math.min(100, this.battery + amount);
      log(`Charged by ${amount} units. Battery level is now: ${this.battery.toFixed(1)}%`);
    }
  }

  // --- Object Instantiation & Execution (like main section) ---
  log("--- OOP Exercises Execution ---");

  const person1 = new Person("Jane Doe", 25);
  const book1 = new Book("The Odyssey", "Homer", 541);
  const car1 = new Car("Toyota", "Camry", 40);
  const eCar1 = new ElectricCar("Lucid", "Air", 75);

  // Q1 & Q3
  log("\n[Q1] Person Properties:");
  log(`Name: ${person1.name}, Age: ${person1.age}`);

  log("\n[Q3] Book Properties:");
  log(`Title: ${book1.title}, Author: ${book1.author}, Pages: ${book1.totalPages}`);

  // Q2
  log("\n[Q2] Person Greeting:");
  person1.greet();

  // Q5
  log("\n[Q5] Book Length Check:");
  log(`Is '${book1.title}' a long book (> 300 pages)? ${book1.isLongBook()}`);

  // Q7
  log("\n[Q7] Car Static Info:");
  Car.info();

  // Q8
  log("\n[Q8] ElectricCar Initial State:");
  log(`Electric Car: ${eCar1.make} ${eCar1.model}, Battery: ${eCar1.battery}%`);
  eCar1.charge(15);

  // Q10
  log("\n--- [Q10] Combined Object Routine ---");
  car1.drive(200);
  eCar1.charge(50);
  book1.read(150);
  book1.read(500); // reading past total pages
  person1.greet();

  log("\n-------------------------------------");
</script>

</body>
</html>
